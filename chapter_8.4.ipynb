# %%
#wap to create class atm and make methods to create pin change pin check balance and withdraw

class atm:
    def __init__(self):
        self.pin=0
        self.balance=0
        self.menu()
    def menu(self):
        print("Enter 1 for creating pin")
        print("Enter 2 for change pin")
        print("Enter 3 for check balance")
        print("Enter 4 for withdraw")
        x=int(input("Enter number:"))
        if x==1:
            self.createpin()
        elif x==2:
            self.changepin()
        elif x==3:
            self.balance()
        elif x==4:
            self.withdraw()
        else:
            exit()
        
    def createpin(self):
        print("create")
        user_pin=int(input("enter your pin:"))
        self.pin=user_pin
        user_balance=int(input("Enter balance:"))
        self.balance=user_balance
        print("pin created....")
        self.menu()
        
    def changepin(self):
        print("change")
        old=int(input("Enter old pin:"))
        if old==self.pin:
            new=int(input("Enter new pin:"))
            self.pin=new
        else:
            print("WRONG!!!!!")
        self.menu()
    def balance(self):
        print("bal")      
#         self.balance=user_balance
        print("rupees ",self.balance)
        self.menu()
    def withdraw(self):
        w=int(input("ENter amount to withdraw:"))
        if w>self.balance:
            print("insufficient balance...")
        else:
            self.balance=self.balance-w
            print("withdrawn=",w)
            print("bal= ",self.balance)
        self.menu()   
        
        
a1=atm()
# Out:
# Enter 1 for creating pin
# Enter 2 for change pin
# Enter 3 for check balance
# Enter 4 for withdraw
# Enter number:1
# create
# enter your pin:111
# Enter balance:100
# pin created....
# Enter 1 for creating pin
# Enter 2 for change pin
# Enter 3 for check balance
# Enter 4 for withdraw
# Enter number:3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-af6da9e0f132> in <module>
#      57
#      58
# ---> 59 a1=atm()
#      60
#
# <ipython-input-4-af6da9e0f132> in __init__(self)
#       5         self.pin=0
#       6         self.balance=0
# ----> 7         self.menu()
#       8     def menu(self):
#       9         print("Enter 1 for creating pin")
#
# <ipython-input-4-af6da9e0f132> in menu(self)
#      13         x=int(input("Enter number:"))
#      14         if x==1:
# ---> 15             self.createpin()
#      16         elif x==2:
#      17             self.changepin()
#
# <ipython-input-4-af6da9e0f132> in createpin(self)
#      30         self.balance=user_balance
#      31         print("pin created....")
# ---> 32         self.menu()
#      33
#      34     def changepin(self):
#
# <ipython-input-4-af6da9e0f132> in menu(self)
#      17             self.changepin()
#      18         elif x==3:
# ---> 19             self.balance()
#      20         elif x==4:
#      21             self.withdraw()
#
# TypeError: 'int' object is not callable

# %%
class Pizza:
    def __init__(self, size, toppings, cheese):
        self.size = size
        self.toppings = toppings
        self.cheese = cheese
        
    def price(self):
        self.cost = 0
        if self.size == 'small':
            self.cost += 50
        elif self.size == 'medium':
            self.cost += 100
        else:
            self.cost += 200
        topping_prices_20 = ['corn', 'tomato', 'onion', 'capsicum']
        topping_prices_50 = ['mushroom', 'olives', 'broccoli']
        for topping in self.toppings:
            if topping in topping_prices_20:
                self.cost += 20
            else:
                self.cost += 50
        #for cheese
        self.cost += 50 * len(self.cheese)
        return self.cost

class Order:
    def __init__(self, name, customerid):
        self.name = name
        self.customerid = customerid

    def order(self, n):
        self.pizzas = [] 
        for i in range(n):
            toppings = []
            cheese = []
            print('Customize Pizza',i+1)
            size = input('Select size: ')
            t = int(input('How many toppings: '))
            for i in range(t):
                toppings.append(input('Enter toppings: '))
            t = int(input('How many cheese: '))
            for i in range(t):
                cheese.append(input('Enter cheese: '))
            self.pizzas.append(Pizza(size, toppings, cheese))

    def bill(self):
        self.total = 0
        count = 1
        for p in self.pizzas:
            print('Pizza', count)
            print("Size:",p.size)
            print("Toppings:",p.toppings)
            print("Cheese:",p.cheese)
            self.total += p.price()
            count += 1
        print('Total bill amount:', self.total)
        
number=int(input("How many pizzas you want to order: "))
order1 = Order('Tejas', 1)
order1.order(number)
order1.bill()

# %%
#sir:
class Atm:
    # constructor
    def __init__(self):
        self.pin=''
        self.balance=0
        self.menu()
    
    def menu(self):
        user_input=input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        if user_input=='1':
            self.create_pin()
        elif user_input=='2':
            self.change_pin()
        elif user_input =='3':
            self.check_balance()
        elif user_input=='4':
            self.withdraw()
        else:
            exit()
    
    def create_pin(self):
        user_pin=input('enter your pin: ')
        self.pin=user_pin
        user_balance=int(input('enter balance: '))
        self.balance=user_balance
        print('Pin created successfully')
        self.menu()
    
    def change_pin(self):
        old_pin=input('Enter old pin: ')
        if old_pin ==self.pin:
            # let him change the pin
            new_pin=input('Enter new pin: ')
            self.pin=new_pin
            print('Pin changed successful')
        else:
            print('Enter correct pin')
        self.menu()
    
    def check_balance(self):
        user_pin=input('Enter your pin: ')
        if user_pin==self.pin:
            print('your balance is: ',self.balance)
        else:
            print('Enter correct pin')
        self.menu()
    
    def withdraw(self):
        user_pin=input('enter the pin')
        if user_pin==self.pin:
            # allow to withdraw
            amount=int(input('Enter the amount to withdraw: '))
            if amount<=self.balance:
                self.balance=self.balance-amount
                print('Withdrawl successful.balance is: ',self.balance)
            else:
                print('Low Balance')
        else:
            print('Enter correct pin')
        self.menu()
        
a=Atm()
# Out:
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#         1
# enter your pin: 111
# enter balance: 100
# Pin created successfully
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#         2
# Enter old pin: 111
# Enter new pin: 1111
# Pin changed successful
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#         3
# Enter your pin: 111
# Enter correct pin
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#         3
# Enter your pin: 1111
# your balance is:  100
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to change pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#         4
# enter the pin1111
# Enter the amount to withdraw: 10
# Withdrawl successful.balance is:  90
