# %% [markdown]
# # CH-10 MATPLOTLIB

# %% [markdown]
# matplotlib is a library for graphical representation

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# actual points are (1,3),(8,10) but we write them as all x together and all y together

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'o')
plt.show()
# this is called marker.
#we wont get lines but instead will get points only

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,marker='o')
plt.show()
#marker='o' gives both line and the dots.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'.')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'X')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'+')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'D')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'d')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'h')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'h',ms=20)
plt.show()
# ms meaning marker size gives bigger pointers

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'h',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o')
plt.show()

# %% [markdown]
#     line style:
#         -  solid line
#         :  dotted line
#         -- dashed line
#         -. dashed dotted
#     color:
#         r red
#         g green
#         b blue
#         c cyan
#         m magenta
#         y yellow
#         k black
#         w white

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',ms=20,mec='r')
plt.show()
#mec: marker edge color

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',ms=20,mec='r',mfc='r')
plt.show()

#mfc: marker face color

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',mec='r',mfc='r')
plt.show()

# if we dont pass xpoints then a takes default value of 0,1,2,3... etc.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,marker='o',mec='r',mfc='r')
plt.show()

# if we dont pass ypoints then it makes x as y and provides default values for x

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle="dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',ls="dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle=":")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle=":",color="m")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle=":",c="g")
plt.show()

# %% [markdown]
#     c supports 140 colors
#     hexcodes also work

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle=":",c="g",linewidth=6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle="--",c="g",lw=5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle="--",c="g",lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-3657f26fe2a1> in <module>
#       3 xpoints=np.array([1,2])
#       4 ypoints=np.array([3,8,1,10])
# ----> 5 plt.plot(xpoints,ypoints,marker='o',mec='r',mfc='b',linestyle="--",c="g",lw=5)
#       6 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...

# %% [markdown]
# ### Make graphs for comparision :

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1,'*',mec='r',mfc='g',ms=25,ls=':',c="b")
plt.plot(y2,"D",ms=28,ls="--",c="g",mec='b',mfc="m")
plt.show()

# %% [markdown]
# ## Labels and Titles:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data")
plt.xlabel("average pulse")
plt.ylabel("calories burnt")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1)
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') #available: 'left', 'center', 'right'
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  #available:  'bottom', 'center', 'top'
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') #available: 'left', 'center', 'right'
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  #available:  'bottom', 'center', 'top'
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') 
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') 
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') 
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  
plt.grid(axis='xy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-bcc5e49e77a6> in <module>
#       9 plt.xlabel("average pulse",fontdict=font2)
#      10 plt.ylabel("calories burnt",fontdict=font2,loc='top')
# ---> 11 plt.grid(axis='xy')
#      12 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in grid(b, which, axis, **kwargs)
#    2654 @_copy_docstring_and_deprecators(Axes.grid)
#    2655 def grid(b=None, which='major', axis='both', **kwargs):
# -> 2656     return gca().grid(b=b, which=which, axis=axis, **kwargs)
#    2657
#    2658
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2888         if len(kwargs):
#    2889             b = True
# -> 2890         cbook._check_in_list(['x', 'y', 'both'], axis=axis)
#    2891         if axis in ['x', 'both']:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
x=np.array([80,85,90,95,100,106,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,marker="o")
plt.title("sports watch data",fontdict=font1,loc='left') 
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("calories burnt",fontdict=font2,loc='top')  
plt.grid(axis='both')  #available:['x', 'y', 'both']
plt.show()

# %% [markdown]
# ### Matplotlib Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.title("g-1")
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.title("g-2")
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,70,40])
plt.subplot(2,3,3)
plt.title("g-3")
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,70,30,40])
plt.subplot(2,3,4)
plt.title("g-4")
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,80,30,40])
plt.subplot(2,3,5)
plt.title("g-5")
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,10,30,40])
plt.subplot(2,3,6)
plt.title("g-6")
plt.plot(x,y)
plt.show()

# %%
# 1 2 3 
# 4 5 6
# sequence
